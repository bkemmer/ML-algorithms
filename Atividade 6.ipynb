# %% [markdown]
# # Atividade 6 - Rede Neural (Softmax)
# Bruno Kemmer NUSP 5910474

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import diabetes
import iris
import hepatitis

# %%
diabetes.main()
# Out:
# Dimensão do treino e teste: (538, 8) (230, 8)
# dimensão de w:  (9,)
#
# Regressão linear s/normalização:
# Acurácia: 0.7565
#
# Regressão linear z_score:
# Acurácia: 0.7565
#
# Regressão linear min_max:
# Acurácia: 0.6522
#
# Regressão logistica z_score:
# Acurácia: 0.7478
#
# Regressão logistica min_max:
# Acurácia: 0.7522
#
# TW-SVM z_score:
# Acurácia: 0.7391
#
# Rede Neural Softmax z_score:
# Época final: 5000
# Custo final: 247.08174854885385
# Acurácia: 0.7478

# %%
iris.main()
# Out:
# Dimensão de X:  (150, 4)
# Dimensão de :  (150, 3)
# Dimensão do treino e teste: (105, 4) (45, 4)
# dimensão de w:  (5, 3)
#
# Regressão linear s/normalização:
# Acurácia: 0.8444
#
# Regressão linear z_score:
# Acurácia: 0.8444
#
# Regressão linear min_max:
# Acurácia: 0.8444
#
# Regressão logistica z_score:
# Acurácia: 0.9778
#
# Regressão logistica min_max:
# Acurácia: 0.9333
#
# Rede Neural Softmax z_score:
# Época final: 5000
# Custo final: 8.155787717930647
# Acurácia: 1.0000

# %%
hepatitis.main()
# Out:
# Dimensão de X:  (155, 19)
# Dimensão de y:  (155,)
# Dimensão do treino e teste: (108, 19) (47, 19)
# dimensão de w:  (20,)
#
# Regressão linear s/normalização:
# Acurácia: 0.8298
#
# Regressão linear z_score:
# Acurácia: 0.8298
#
# Regressão linear min_max:
# Acurácia: 0.1915
#
# Regressão logistica z_score:
# Acurácia: 0.7872
#
# Regressão logistica min_max:
# Acurácia: 0.8298
# Época final: 5000
# Custo final: 21.929763637910476
# Rede Neural Softmax z_score:
# Acurácia: 0.7872
